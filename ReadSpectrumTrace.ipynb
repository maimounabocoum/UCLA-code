# %%
import numpy as np
import matplotlib.pyplot as plt

# Full Path to your file
filename = r"D:\ucla data\spectrum\ArgonLS_63p3dBm_5900torr_500kHzdrive_25msIntTime_ST006871__1__19-46-08-601.txt"

# Read file
with open(filename, "r") as f:
    lines = f.readlines()

# Find beginning of spectral data
for i, line in enumerate(lines):
    if "Begin Spectral Data" in line:
        start_index = i + 1
        break

# Read numerical data
data = np.loadtxt(lines[start_index:])

# Separate columns
wavelength = data[:, 0]
intensity = data[:, 1]

# Plot spectrum
plt.figure(figsize=(10,5))
plt.plot(wavelength, intensity)

plt.xlabel("Wavelength (nm)")
plt.ylabel("Intensity")
plt.title("Spectrometer Spectrum")

plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# ---------------------------------------------------
# List of files
# ---------------------------------------------------

filenames = [
    r"D:\ucla data\spectrum\ArgonLS_56p9dBm_5900torr_400kHzdrive_100msIntTime_ST006871__0__19-23-23-685.txt",
    r"D:\ucla data\spectrum\ArgonLS_60p1dBm_5900torr_400kHzdrive_8msIntTime_ST006871__0__19-29-05-825.txt",
    r"D:\ucla data\spectrum\ArgonLS_60p1dBm_5900torr_400kHzdrive_100msIntTime_ST006871__0__19-28-07-317.txt",
]

# ---------------------------------------------------
# Create figure
# ---------------------------------------------------

plt.figure(figsize=(10,5))

# ---------------------------------------------------
# Loop over files
# ---------------------------------------------------

for filename in filenames:

    # Read file
    with open(filename, "r") as f:
        lines = f.readlines()

    # Find beginning of spectral data
    for i, line in enumerate(lines):
        if "Begin Spectral Data" in line:
            start_index = i + 1
            break

    # Read numerical data
    data = np.loadtxt(lines[start_index:])

    # Separate columns
    wavelength = data[:, 0]
    intensity = data[:, 1]

    # Optional: use filename as legend
    label = filename.split("\\")[-1]

    # Plot
    plt.plot(wavelength, intensity, label=label)

# ---------------------------------------------------
# Figure formatting
# ---------------------------------------------------

plt.xlabel("Wavelength (nm)")
plt.ylabel("Intensity")
plt.title("Spectrometer Spectra")

plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# ---------------------------------------------------
# List of files
# ---------------------------------------------------

filenames = [
    r"D:\ucla data\spectrum\ArgonLS_63p3dBm_5900torr_500kHzdrive_1p56msIntTime_ST006871__0__19-44-51-325.txt",
    r"D:\ucla data\spectrum\ArgonLS_63p3dBm_5900torr_500kHzdrive_10msIntTime_ST006871__0__19-45-34-044.txt",
    r"D:\ucla data\spectrum\ArgonLS_63p3dBm_5900torr_500kHzdrive_25msIntTime_ST006871__0__19-45-58-918.txt",

]

# ---------------------------------------------------
# Create figure
# ---------------------------------------------------

plt.figure(figsize=(10,5))

# ---------------------------------------------------
# Loop over files
# ---------------------------------------------------

for filename in filenames:

    # Read file
    with open(filename, "r") as f:
        lines = f.readlines()

    # Find beginning of spectral data
    for i, line in enumerate(lines):
        if "Begin Spectral Data" in line:
            start_index = i + 1
            break

    # Read numerical data
    data = np.loadtxt(lines[start_index:])

    # Separate columns
    wavelength = data[:, 0]
    intensity = data[:, 1]

    # Optional: use filename as legend
    label = filename.split("\\")[-1]

    # Plot
    plt.plot(wavelength, intensity, label=label)

# ---------------------------------------------------
# Figure formatting
# ---------------------------------------------------

plt.xlabel("Wavelength (nm)")
plt.ylabel("Intensity")
plt.title("Spectrometer Spectra")

plt.grid(True)
plt.legend()

plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Full Path to your file
filename = r"D:\ucla data\spectrum\ArgonLS_63p3dBm_5900torr_500kHzdrive_25msIntTime_ST006871__1__19-46-08-601.txt"
#filename = r"D:\ucla data\spectrum\ArgonLS_60p1dBm_5900torr_400kHzdrive_8msIntTime_ST006871__0__19-29-05-825.txt"


# Read file
with open(filename, "r") as f:
    lines = f.readlines()

# Find beginning of spectral data
for i, line in enumerate(lines):
    if "Begin Spectral Data" in line:
        start_index = i + 1
        break

# Read numerical data
data = np.loadtxt(lines[start_index:])

# Separate columns
wavelength = data[:, 0]
intensity = data[:, 1]

fig, ax = plt.subplots()

ax.plot(wavelength, intensity)

plt.title("Click on the peak")

point = plt.ginput(1)

print(point)

plt.show()
# Out:
# []
